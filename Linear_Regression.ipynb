# %%
import pandas as pd
import numpy as np
boston = pd.read_csv("BostonHousing.csv")
boston.shape
# Out:
# (506, 14)

# %%
import matplotlib.pyplot as plt
boston.plot(subplots=True, figsize=(10, 10))
plt.show()
